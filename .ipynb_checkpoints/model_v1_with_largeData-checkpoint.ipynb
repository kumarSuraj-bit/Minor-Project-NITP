# %% [markdown]
# ## Importing Important packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import cv2

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Lambda, Conv2D, MaxPooling2D, Dropout, Dense, Flatten
from tensorflow.keras.utils import plot_model

import os #for reading files

# %% [markdown]
# Activating the GPU for fast Training

# %%
physical_device = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_device[0],True)

# %% [markdown]
# ## Data Loading and Prepare it to feed in model

# %%
data = pd.read_csv('driving_log.csv',names=['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed'])

# %%
data.shape
# Out:
# (1972, 7)

# %%
data
# Out:
#                                                  center  \
# 0     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 2     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 3     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 4     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# ...                                                 ...
# 1967  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1968  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1969  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1970  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1971  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
#
#                                                    left  \
# 0     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 2     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 3     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 4     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# ...                                                 ...
# 1967  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1968  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1969  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1970  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
# 1971  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...
#
#                                                   right  steering  throttle  \
# 0     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 1     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 2     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 3     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 4     C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# ...                                                 ...       ...       ...
# 1967  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 1968  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 1969  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 1970  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
# 1971  C:\Users\suraj\Desktop\MinorProjectNITP2022\IM...       0.0       0.0
#
#       reverse     speed
# 0         0.0  0.000005
# 1         0.0  0.000004
# 2         0.0  0.000001
# 3         0.0  0.000009
# 4         0.0  0.000027
# ...       ...       ...
# 1967      0.0  5.359535
# 1968      0.0  5.314921
# 1969      0.0  5.281695
# 1970      0.0  5.237708
# 1971      0.0  5.194073
#
# [1972 rows x 7 columns]

# %%
X = data[['center', 'left', 'right']].values

# %%
X
# Out:
# array([['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_10_51_325.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_10_51_325.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_10_51_325.jpg'],
#        ['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_10_51_391.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_10_51_391.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_10_51_391.jpg'],
#        ['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_10_51_460.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_10_51_460.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_10_51_460.jpg'],
#        ...,
#        ['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_13_12_931.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_13_12_931.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_13_12_931.jpg'],
#        ['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_13_13_004.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_13_13_004.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_13_13_004.jpg'],
#        ['C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\center_2022_11_20_02_13_13_118.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\left_2022_11_20_02_13_13_118.jpg',
#         'C:\\Users\\suraj\\Desktop\\MinorProjectNITP2022\\IMG\\right_2022_11_20_02_13_13_118.jpg']],
#       dtype=object)

# %%
img1 = mpimg.imread(X[0][0])
img2 = mpimg.imread(X[0][1])
img3 = mpimg.imread(X[0][2])

img1.shape
# Out:
# (160, 320, 3)

# %%
img1, img2, img3
# Out:
# (array([[[116, 145, 185],
#          [116, 145, 185],
#          [115, 144, 184],
#          ...,
#          [ 12,  11,   7],
#          [ 33,  32,  28],
#          [  1,   0,   0]],
#
#         [[116, 145, 185],
#          [116, 145, 185],
#          [116, 145, 185],
#          ...,
#          [  1,   0,   0],
#          [  5,   4,   0],
#          [ 22,  21,  17]],
#
#         [[117, 146, 186],
#          [117, 146, 186],
#          [117, 146, 186],
#          ...,
#          [ 51,  50,  46],
#          [  7,   6,   2],
#          [  1,   0,   0]],
#
#         ...,
#
#         [[ 91,  97,  87],
#          [ 89,  95,  85],
#          [ 78,  84,  74],
#          ...,
#          [127, 128, 112],
#          [107, 108,  92],
#          [103, 104,  88]],
#
#         [[ 75,  81,  71],
#          [ 67,  73,  63],
#          [ 67,  73,  63],
#          ...,
#          [ 92,  93,  77],
#          [100, 101,  85],
#          [ 91,  92,  76]],
#
#         [[ 54,  60,  48],
#          [ 47,  53,  43],
#          [ 63,  69,  59],
#          ...,
#          [114, 115,  99],
#          [ 87,  88,  72],
#          [ 82,  83,  67]]], dtype=uint8),
#  array([[[116, 145, 185],
#          [116, 145, 185],
#          [115, 144, 184],
#          ...,
#          [  3,   4,   0],
#          [ 20,  21,  15],
#          [ 25,  26,  20]],
#
#         [[116, 145, 185],
#          [116, 145, 185],
#          [116, 145, 185],
#          ...,
#          [ 22,  23,  17],
#          [  0,   1,   0],
#          [ 24,  25,  19]],
#
#         [[117, 146, 186],
#          [117, 146, 186],
#          [117, 146, 186],
#          ...,
#          [ 13,  16,   9],
#          [ 19,  20,  14],
#          [ 36,  37,  31]],
#
#         ...,
#
#         [[100, 105,  98],
#          [112, 117, 110],
#          [124, 129, 122],
#          ...,
#          [164, 176, 166],
#          [156, 168, 158],
#          [146, 158, 148]],
#
#         [[120, 125, 118],
#          [106, 111, 104],
#          [107, 112, 105],
#          ...,
#          [147, 159, 149],
#          [147, 160, 150],
#          [157, 170, 160]],
#
#         [[ 99, 104,  97],
#          [ 64,  69,  62],
#          [ 72,  77,  70],
#          ...,
#          [144, 157, 147],
#          [143, 156, 146],
#          [162, 175, 166]]], dtype=uint8),
#  array([[[116, 145, 185],
#          [116, 145, 185],
#          [115, 144, 184],
#          ...,
#          [  6,  10,   0],
#          [  1,   5,   0],
#          [  0,   3,   0]],
#
#         [[116, 145, 185],
#          [116, 145, 185],
#          [116, 145, 185],
#          ...,
#          [  0,   2,   0],
#          [ 11,  15,   1],
#          [ 60,  64,  50]],
#
#         [[117, 146, 186],
#          [117, 146, 186],
#          [117, 146, 186],
#          ...,
#          [ 52,  55,  46],
#          [ 32,  35,  26],
#          [ 32,  35,  26]],
#
#         ...,
#
#         [[175, 187, 173],
#          [159, 171, 157],
#          [142, 154, 142],
#          ...,
#          [255, 238, 227],
#          [255, 242, 232],
#          [255, 242, 232]],
#
#         [[171, 183, 169],
#          [154, 166, 152],
#          [138, 150, 136],
#          ...,
#          [255, 250, 246],
#          [238, 219, 215],
#          [255, 248, 245]],
#
#         [[168, 180, 166],
#          [151, 163, 149],
#          [136, 148, 134],
#          ...,
#          [250, 244, 244],
#          [255, 252, 255],
#          [255, 251, 255]]], dtype=uint8))

# %%
fig = plt.figure(figsize=(20, 20))

fig.add_subplot(1, 3, 1)
plt.imshow(img2)
plt.title("Left")

fig.add_subplot(1, 3, 2)
plt.imshow(img1)
plt.title("Center")

fig.add_subplot(1, 3, 3)
plt.imshow(img3)
plt.title("Right")
# Out:
# Text(0.5, 1.0, 'Right')

# %%
y = data['steering'].values

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state=32)

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## Model used by NVIDIA
#
#     Image normalization to avoid saturation and make gradients work better.
#
#     Convolution: 5x5, filter: 24, strides: 2x2, activation: ELU
#     Convolution: 5x5, filter: 36, strides: 2x2, activation: ELU
#     Convolution: 5x5, filter: 48, strides: 2x2, activation: ELU
#     Convolution: 3x3, filter: 64, strides: 1x1, activation: ELU
#     Convolution: 3x3, filter: 64, strides: 1x1, activation: ELU
#     Drop out (0.5)
#     Fully connected: neurons: 100, activation: ELU
#     Fully connected: neurons: 50, activation: ELU
#     Fully connected: neurons: 10, activation: ELU
#     Fully connected: neurons: 1 (output)
#
#     # the convolution layers are meant to handle feature engineering
#     the fully connected layer for predicting the steering angle.
#     dropout avoids overfitting
#     ELU(Exponential linear unit) function takes care of the Vanishing gradient problem.

# %%
IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS = 160, 320, 3
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

# %%
def build_model():
    
    model = Sequential()
    model.add(Conv2D(24, 5, 5, activation='elu', padding = 'same',input_shape=INPUT_SHAPE))
    model.add(Conv2D(36, 5, 5, activation='elu', padding = 'same'))
    model.add(Conv2D(48, 5, 5, activation='elu', padding = 'same'))
    model.add(Conv2D(64, 3, 3, activation='elu', padding = 'same'))
    model.add(Conv2D(64, 3, 3, activation='elu', padding = 'same'))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(100, activation='elu'))
    model.add(Dense(50, activation='elu'))
    model.add(Dense(10, activation='elu'))
    model.add(Dense(1))
    model.summary()
    
    return model

# %%
def Preprocess(image):
    
    image = mpimg.imread(image) #Load RGB images from a file
    image = cv2.cvtColor(image, cv2.COLOR_RGB2YUV) # Convert the image from RGB to YUV (This is what the NVIDIA model does)
    image = image/255 # normalize pixels value between 0 & 1
    return image

# %%
def batch_generator(X_train, y_train, batch_size):
    """
    Generate training image and associated steering angles
    """
    images = list()
    steers = list()

    while 1:
        batch_count = 0
        for index in range(X_train.shape[0]):
        
            center, left, right = X_train[index]
            steering_angle = y_train[index]
            
            # image preprocess
            center_image = Preprocess(center)
            left_image = Preprocess(left)
            right_image = Preprocess(right)
                
            #add the image and steering angle to the batch
            images.append(center_image)
            images.append(left_image)
            images.append(right_image)
            
            steers.append(steering_angle)
            steers.append(steering_angle)
            steers.append(steering_angle)
            
            batch_count = batch_count + 1
            
            if batch_count == batch_size:
                batch_count = 0
                yield (np.array(images),np.array(steers))
                images = list() 
                steers = list()

# %%
X_train.shape,X_valid.shape
# Out:
# ((1479, 3), (493, 3))

# %%
#build model
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 64, 24)        1824
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 13, 36)         21636
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 2, 3, 48)          43248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 1, 64)          27712
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 64)          36928
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 100)               6500
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 143,419
# Trainable params: 143,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# training model on data 
model.compile(loss='mean_squared_error', optimizer='Adam',metrics=['accuracy'])
    
batch_size = 10
steps = X_train.shape[0]//batch_size

#Fits the model on data generated batch-by-batch by a Python generator.
generator = batch_generator(X_train, y_train, batch_size=10)

model_history = model.fit(
                            generator,
                            epochs = 30,
                            steps_per_epoch=steps,
                         )
# Out:
# Epoch 1/30
# 147/147 [==============================] - 24s 118ms/step - loss: 0.0203 - accuracy: 0.8095
# Epoch 2/30
# 147/147 [==============================] - 18s 117ms/step - loss: 0.0180 - accuracy: 0.8100
# Epoch 3/30
# 147/147 [==============================] - 17s 113ms/step - loss: 0.0168 - accuracy: 0.8100
# Epoch 4/30
# 147/147 [==============================] - 21s 143ms/step - loss: 0.0150 - accuracy: 0.8100
# Epoch 5/30
# 147/147 [==============================] - 16s 105ms/step - loss: 0.0126 - accuracy: 0.8100
# Epoch 6/30
# 147/147 [==============================] - 15s 102ms/step - loss: 0.0099 - accuracy: 0.8100
# Epoch 7/30
# 147/147 [==============================] - 15s 103ms/step - loss: 0.0077 - accuracy: 0.8100
# Epoch 8/30
# 147/147 [==============================] - 16s 105ms/step - loss: 0.0064 - accuracy: 0.8100
# Epoch 9/30
# 147/147 [==============================] - 15s 100ms/step - loss: 0.0051 - accuracy: 0.8100
# Epoch 10/30
# 147/147 [==============================] - 15s 100ms/step - loss: 0.0042 - accuracy: 0.8100
# Epoch 11/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.0040 - accuracy: 0.8100
# Epoch 12/30
# 147/147 [==============================] - 17s 116ms/step - loss: 0.0047 - accuracy: 0.8100
# Epoch 13/30
# 147/147 [==============================] - 18s 121ms/step - loss: 0.0041 - accuracy: 0.8100
# Epoch 14/30
# 147/147 [==============================] - 15s 99ms/step - loss: 0.0030 - accuracy: 0.8100
# Epoch 15/30
# 147/147 [==============================] - 15s 104ms/step - loss: 0.0030 - accuracy: 0.8100
# Epoch 16/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.0026 - accuracy: 0.8100
# Epoch 17/30
# 147/147 [==============================] - 15s 100ms/step - loss: 0.0023 - accuracy: 0.8100
# Epoch 18/30
# 147/147 [==============================] - 15s 104ms/step - loss: 0.0021 - accuracy: 0.8100
# Epoch 19/30
# 147/147 [==============================] - 16s 107ms/step - loss: 0.0020 - accuracy: 0.8100
# Epoch 20/30
# 147/147 [==============================] - 16s 106ms/step - loss: 0.0019 - accuracy: 0.8100
# Epoch 21/30
# 147/147 [==============================] - 16s 110ms/step - loss: 0.0018 - accuracy: 0.8100
# Epoch 22/30
# 147/147 [==============================] - 16s 110ms/step - loss: 0.0019 - accuracy: 0.8100
# Epoch 23/30
# 147/147 [==============================] - 16s 108ms/step - loss: 0.0022 - accuracy: 0.8100
# Epoch 24/30
# 147/147 [==============================] - 15s 104ms/step - loss: 0.0021 - accuracy: 0.8100
# Epoch 25/30
# 147/147 [==============================] - 16s 111ms/step - loss: 0.0017 - accuracy: 0.8100
# Epoch 26/30
# 147/147 [==============================] - 16s 112ms/step - loss: 0.0019 - accuracy: 0.8100
# Epoch 27/30
# 147/147 [==============================] - 18s 122ms/step - loss: 0.0019 - accuracy: 0.8100
# Epoch 28/30
# 147/147 [==============================] - 18s 124ms/step - loss: 0.0016 - accuracy: 0.8100
# Epoch 29/30
# 147/147 [==============================] - 16s 110ms/step - loss: 0.0015 - accuracy: 0.8100
# Epoch 30/30
# 147/147 [==============================] - 15s 103ms/step - loss: 0.0013 - accuracy: 0.8100
# Wall time: 8min 14s

# %%
model.save('model_v1_with_large_data.h5')

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(model_history.history['accuracy'])

# %%
plt.plot(model_history.history['loss'])
